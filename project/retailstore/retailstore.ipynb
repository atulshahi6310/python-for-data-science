# %% [markdown]
# Perfect 🎯 Let’s start **Day 10 of your 15-Day Python Data Challenge**!
#
# For Day 10, I’ll design a **Retail Sales Analysis Problem** 🛒📊.
#
# ---
#
# ### 📝 Problem Statement (Day 10):
#
# A retail store wants to analyze its **sales data** for the past 20 days.
# You are tasked to:
#
# 1. **Load & explore the dataset** using **Pandas**.
# 2. Find the **total sales per product category**.
# 3. Identify the **day with maximum revenue**.
# 4. Calculate the **average order value**.
# 5. Create **visualizations** using Matplotlib & Seaborn:
#
#    * Bar chart → Sales per category
#    * Line plot → Daily revenue trend
#    * Heatmap → Correlation between quantity, price & revenue
#
# 📊 **Objective**: Help the store understand **which categories perform best** and **when peak sales occur**.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("retail_sales_day10.csv")


print(df.head())




total_revenue = df["Revenue"].sum()
print("Total Revenue:", total_revenue)


top_products = df.groupby("Product")["Revenue"].sum().sort_values(ascending=False).head(5)
print("\nTop 5 Products by Revenue:\n", top_products)

category_revenue = df.groupby("Category")["Revenue"].sum()
print("\nRevenue by Category:\n", category_revenue)
# Out:
#          Date     Category     Product  Quantity  Price  Revenue
# 0  2025-02-01  Electronics  Smartphone         2    182      364
# 1  2025-02-01    Groceries       Bread         5   1024     5120
# 2  2025-02-01   Home Decor        Lamp         4    204      816
# 3  2025-02-01    Groceries       Bread         5   1885     9425
# 4  2025-02-01     Clothing       Jeans         3    987     2961
# Total Revenue: 420827
#
# Top 5 Products by Revenue:
#  Product
# Jacket     46016
# Laptop     45206
# T-Shirt    36752
# Chair      35430
# Jeans      34252
# Name: Revenue, dtype: int64
#
# Revenue by Category:
#  Category
# Clothing       117020
# Electronics     83516
# Groceries       71860
# Home Decor      82441
# Sports          65990
# Name: Revenue, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=category_revenue.index, y=category_revenue.values, palette="viridis")
plt.title("Revenue by Category")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20768\1898378706.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_revenue.index, y=category_revenue.values, palette="viridis")

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=top_products.index, y=top_products.values, palette="magma")
plt.title("Top 5 Products by Revenue")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20768\3105746706.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_products.index, y=top_products.values, palette="magma")

# %%
daily_revenue = df.groupby("Date")["Revenue"].sum()
plt.figure(figsize=(10,5))
sns.lineplot(x=daily_revenue.index, y=daily_revenue.values, marker="o")
plt.title("Daily Revenue Trend")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()
